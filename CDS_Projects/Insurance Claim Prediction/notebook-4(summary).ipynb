# %% [markdown]
# ## Insurance Claim Prediction-Predict if a driver will file an insurance claim next year.

# %% [markdown]
# ## 1 Project Summary
#
# Inaccuracies in car insurance company’s claim predictions raise the cost of insurance for good drivers and reduce the price for bad ones.In this Dataset, we are challenged to build a model that predicts the probability that a driver will initiate an auto insurance claim in the following year.A more accurate prediction will allow Insurance Company to further tailor their prices, and hopefully make auto insurance coverage more accessible to more drivers.
#
# The input file is given as an excel file(.CSV) which contains 595212 records of Driviers and 59 features which are well-defined. The shape of the data is 595212x59. These 59 features are classified as 15 nominal, 18 binary, 16 ordinal, 10 continuous. Out of these ID is irrelevant feature while considering Performance.
#
# The dataset is a complete one with no null values. Correlation is used to find the relationship between the features and various analysis is done to indicate the performance rating with other features.
#
# The Machine Learning Classifier Models are used to find the accuracy of the data. The models used are 1.Logestic Regression 2.DecisionTreeClassifier 3.RandomForestClassifier 4.XGBoost Classifier
#
# ### From these models RandomForestClassifier algorithm gives better accuracy of 96%
#
# Various steps such as Preprocessing, Encoding , prediction using Machine Learning models and Visualization are used to achieve our objective.

# %% [markdown]
# ## 2 Requirement
#
# The input data which is given by Internship team Datamites. It is an excel file(.csv) with 595219 rows and 59 columns. Recent years, the Driving performance of drivers is becoming a growing concerns among the top Insurance companies. So the data is analyzed and to find the Insurance claim by the drivers based on the data provided. The data is analyzed with Jupyter notebook in Python language.

# %% [markdown]
# ## Analysis
#
# The analysis is done by analyzing the various features of the data. It has 59 features which plays important role in analysis of data with many prespectives. Many packages such as numpy, pandas,etc., are used to analyze the fearures. The features are categorized into Numerical and Categorical Datas.
#
# #### Numerical Data
#
# Numerical features are the values which varies in a particular range and classified as discrete, continuous, or timeseries based. The Numerical Features as follows,
#
# - ps_reg_01
# - ps_reg_02
# - ps_reg_03
# - ps_car_12
# - ps_car_13
# - ps_car_14
# - ps_car_15
# - ps_calc_01
# - ps_calc_02
# - ps_calc_03
#
# #### Catrgorical Data
#
# Categorical features are those which classify values into sets of similar samples and the values are nominal, ordinal, ratio, or interval based. The categorical features as follows,
#
# ##### Nominal
# - ps_ind_02_cat
# - ps_ind_04_cat
# - ps_ind_05_cat
# - ps_car_01_cat
# - ps_car_02_cat
# - ps_car_03_cat
# - ps_car_04_cat
# - ps_car_05_cat
# - ps_car_06_cat
# - ps_car_07_cat
# - ps_car_08_cat
# - ps_car_09_cat
# - ps_car_10_cat
# - ps_car_11_cat
#
# ##### Ordinal
# - ps_ind_01
# - ps_ind_03
# - ps_ind_14
# - ps_ind_15
# - ps_car_11
# - ps_calc_04
# - ps_calc_05
# - ps_calc_06
# - ps_calc_07
# - ps_calc_08
# - ps_calc_09
# - ps_calc_10
# - ps_calc_11
# - ps_calc_12
# - ps_calc_13
# - ps_calc_14
#
# ##### Binary
# - target
# - ps_ind_06_bin
# - ps_ind_07_bin
# - ps_ind_08_bin
# - ps_ind_09_bin
# - ps_ind_10_bin
# - ps_ind_11_bin
# - ps_ind_12_bin
# - ps_ind_13_bin
# - ps_ind_16_bin
# - ps_ind_17_bin
# - ps_ind_18_bin
# - ps_calc_15_bin
# - ps_calc_16_bin
# - ps_calc_17_bin
# - ps_calc_18_bin
# - ps_calc_19_bin
# - ps_calc_20_bin
#
# ## Data Cleaning
#
# The Data cleaning is the part of the Data science project where the workflow the project go through this stage. because the damaged and missing data will lead to the disaster in the accuracy and quality of the model. If the data is already structured and cleaned, there is no need for the data cleaning. In this case, the given data is well structured and cleaned and there are no missing data present in this data.
#
# ## Analysis by Visualization
#
# To perform the analysis by the visualisation of the data in various forms are used in this project. It is done by distributing the data and visualize using plotting with matplotlib package and PowerBI.
#
# ## Machine Learning Model
# The machine learning models used in this project are
#
# - Logestic Regression with Smote
# - DecisionTreeClassifier with PCA
# - RandomForestClassifier
# - XGBoost Classifier with PCA
#
# All these machine learning algorithms are best for classification and labelled data. The train and test data are divided and fitted into the model and passed through the machine learning. The predicted data and test data achieved the accuracy rate of,
#
# - Logestic Regression with Smote
#    over sampling - 60%
#    under sampling -37%
# - DecisionTreeClassifier with PCA -96%
# - RandomForestClassifier-96%
# - XGBoost Classifier with PCA-96%

# %% [markdown]
# ## 3 Summary

# %% [markdown]
# The 4 machine learning model has been fitted and predicted with the accuracy score. The objective of this project is to predict the results from the analysis and machine learning model.
#
# ### Objective 1: Over all Data Analysis
# we have to analyze the data from all in the category. The features can be separated based on type of data respectively. The performance analysis by the data as follows,
#
# As we cannot pick only the highly corelated features with our target feature, because input featres are independent over depandant feature(target or output) ie; they have very little or no multi collinearity
#
# The data is basically divided into 2 type as follows
# - categorical
# - Numerical
#
# - **Categorical** - Most of our data set deals with this kind of data. It can be further classified into 3 types W.R.T our data set
# - Nominal
# - Ordinal
# - Binary
#
# - **Numerical** - Less number of our data set deals with numerical,
# - Continuous (both int and float)
#
# ### Objective 2: Top 7 important features affecting the Insurance claim
# The top seven important features affecting the model with highest corelation between them are,
#
# - ps_ind_14
# - ps_ind_17_bin
# - ps_ind_18_bin
# - ps_reg_03
# - ps_car_12
# - ps_car_13
# - ps_car_15
#
# ### Objective 3: A Trained model which can predict the Insurance claim
# The trained model is created using the machine learning algorithm as follows with the accuracy score,
#
# - Logestic Regression with Smote over sampling - 60% under sampling -37%
# - DecisionTreeClassifier with PCA -96%
# - RandomForestClassifier-96%
# - XGBoost Classifier with PCA-96%
# - **RandomForestClassifier gives better Accuracy**
#
# ### Objective 4: Recommendations
