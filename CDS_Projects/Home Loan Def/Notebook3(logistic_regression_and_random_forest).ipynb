# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel

# %%
data = pd.read_csv('/content/drive/MyDrive/home loan project /apptrain_data')
data.head()
# Out:
#    SK_ID_CURR  TARGET  NAME_CONTRACT_TYPE  ...  STATUS_5  STATUS_C  STATUS_X
# 0      100002       1                   0  ...       0.0      23.0      15.0
# 1      100003       0                   0  ...       0.0       0.0       0.0
# 2      100004       0                   1  ...       0.0       0.0       0.0
# 3      100006       0                   0  ...       0.0       0.0       0.0
# 4      100007       0                   0  ...       0.0       0.0       0.0
#
# [5 rows x 199 columns]

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Columns: 199 entries, SK_ID_CURR to STATUS_X
# dtypes: float64(144), int64(55)
# memory usage: 466.9 MB

# %%
mat = data.corr()

# %%
target= data.pop('TARGET')
target
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 307506    0
# 307507    0
# 307508    0
# 307509    1
# 307510    0
# Name: TARGET, Length: 307511, dtype: int64

# %%
data.head()
# Out:
#    SK_ID_CURR  NAME_CONTRACT_TYPE  CODE_GENDER  ...  STATUS_5  STATUS_C  STATUS_X
# 0      100002                   0            1  ...       0.0      23.0      15.0
# 1      100003                   0            0  ...       0.0       0.0       0.0
# 2      100004                   1            1  ...       0.0       0.0       0.0
# 3      100006                   0            0  ...       0.0       0.0       0.0
# 4      100007                   0            1  ...       0.0       0.0       0.0
#
# [5 rows x 198 columns]

# %%
X = data
y = target

# %%
y
# Out:
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 307506    0
# 307507    0
# 307508    0
# 307509    1
# 307510    0
# Name: TARGET, Length: 307511, dtype: int64

# %%
X
# Out:
#         SK_ID_CURR  NAME_CONTRACT_TYPE  ...  STATUS_C  STATUS_X
# 0           100002                   0  ...      23.0      15.0
# 1           100003                   0  ...       0.0       0.0
# 2           100004                   1  ...       0.0       0.0
# 3           100006                   0  ...       0.0       0.0
# 4           100007                   0  ...       0.0       0.0
# ...            ...                 ...  ...       ...       ...
# 307506      456251                   0  ...       0.0       0.0
# 307507      456252                   0  ...       0.0       0.0
# 307508      456253                   0  ...      57.0      13.0
# 307509      456254                   0  ...      29.0       0.0
# 307510      456255                   0  ...     213.0      17.0
#
# [307511 rows x 198 columns]

# %%
y.shape
# Out:
# (307511,)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
X_train.shape
# Out:
# (230633, 198)

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
model = LogisticRegression(solver='saga',max_iter=10000)
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# 0.9197299617575899

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     70709
#            1       0.00      0.00      0.00      6169
#
#     accuracy                           0.92     76878
#    macro avg       0.46      0.50      0.48     76878
# weighted avg       0.85      0.92      0.88     76878

# %%
print(confusion_matrix(y_test,y_predict))
# Out:
# [[70707     2]
#  [ 6169     0]]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
accuracy_score(y_test,y_predict)
# Out:
# 0.9197559770025234

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     70709
#            1       0.00      0.00      0.00      6169
#
#     accuracy                           0.92     76878
#    macro avg       0.46      0.50      0.48     76878
# weighted avg       0.85      0.92      0.88     76878

# %%
print(confusion_matrix(y_test,y_predict))
# Out:
# [[70705     4]
#  [ 6165     4]]
