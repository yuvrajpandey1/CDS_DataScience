# %% [markdown]
# ## Inventory management -> Keeping Inventory of spare in various service centre
# to the market demand is always a challenge as most service centres spends significant amount in spare parts inventory costs

# %% [markdown]
# ### 1.Project Summary

# %% [markdown]
# An existential problem for Inventory management is  Keeping Inventory of spare in various service centre to the market demand is always a challenge as most service centres spends significant amount in spare parts inventory costs. In spite of this, availability of spare parts is been one of the problem areas.

# %% [markdown]
# The input file is given as Database details Port No 18.136.157.135 which contain data for 28482 columns and 7 rows which contain
# Data columns (total 7 columns):
#
# Invoice Date 28482 non-null datetime64[ns]
#
# Job Card Date 28482 non-null datetime64[ns]
#
# Business Partner Name 28482 non-null object
#
# Vehicle No. 28484 non-null object
#
# Vehicle Model 28482 non-null object
#
# Current KM Reading 28482 non-null float64
#
# INVOICE LINE TEXT 28449 non-null object

# %% [markdown]
# The Machine Learning Models are used to find the accuracy of the data. The models used are
#
# 1.Prophet
#
# 2.LSTM
#
# 3.ARIMA
#
# 4.Ar

# %% [markdown]
# #### From these models ARIMA algorithm gives better accuracy of 1454 Mean Sq.

# %% [markdown]
# Various steps such as Preprocessing, Encoding , prediction using Machine Learning models and Visualization are used to achieve our objective.

# %% [markdown]
# ## 2.Requirement

# %% [markdown]
# The input data which is given by Internship team Datamites. It is an database form with 28484 entries rows and 7 columns. The case business case is on the inventory management. Keeping
# Inventory of spare in various service centre to the market demand is
# always a challenge as most service centres spends significant amount
# in spare parts inventory costs. In spite of this, availability of spare
# parts is been one of the problem areas. The data is analyzed with Jupyter notebook in Python language.

# %% [markdown]
# ### Analysis

# %% [markdown]
# The analysis is done by analyzing the various features of the data. It has 7 features which plays important role in analysis of data with many prespectives. Many packages such as numpy, pandas,etc., are used to analyze the fearures. The features are categorized into Numerical and Categorical Datas.

# %% [markdown]
# ### Feature Details:

# %% [markdown]
# RangeIndex: 28484 entries, 0 to 28483
#
# Data columns (total 7 columns):
#
# Invoice Date 28482 non-null datetime64[ns]
#
# Job Card Date 28482 non-null datetime64[ns]
#
# Business Partner Name 28482 non-null object
#
# Vehicle No. 28484 non-null object
#
# Vehicle Model 28482 non-null object
#
# Current KM Reading 28482 non-null float64
#
# INVOICE LINE TEXT 28449 non-null object

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# The Data cleaning is the part of the Data science project where the workflow the project go through this stage. because the damaged and missing data will lead to the disaster in the accuracy and quality of the model. If the data is already structured and cleaned, there is no need for the data cleaning. In this case, the given data is well structured and cleaned and there are no missing data present in this data.

# %% [markdown]
# ### Machine Learning Model

# %% [markdown]
# The machine learning models used in this project are
#
# 1.Prophet
#
# 2.LSTM
#
# 3.ARIMA
#
# 4.Ar

# %% [markdown]
# All these machine learning algorithms are best for forcasting data. The train and test data are divided and fitted into the model and passed through the machine learning. The predicted data and test data achieved the accuracy rate of,
#
# 1. Prophet ->
#
#
# 2. LSTM -> Root Mean square error of LSTM is 3.52
#
#
# 3. ARIMA -> Root Mean square error of ARIMA is 1454
#
#
# 4. AR -> Root Mean square error of AR is 109.53

# %% [markdown]
# ## 3. Summary

# %% [markdown]
# The 4 machine learning model has been fitted and predicted with the accuracy score. The objective of this project is to predict the results from the analysis and machine learning model.
