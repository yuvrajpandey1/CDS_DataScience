# %% [markdown]
# ## Game Winner Prediction - Predict finishing placement based on final stats

# %% [markdown]
# ## 1. Project summary

# %% [markdown]
# This is a PUBG game data set. The data set contains a large amount of anonymized game stats of a single player with all match type. Our target here to create a ML model to predict the finishing placement of a player based on the final stats.
#
# The input file is given as an excel file(.CSV) which contains 4446965 records of Driviers and 29 features which are well-defined. The shape of the data is 4446965x29. These 29 features are classified as 4 categorical and 25 continuous. Out of these ID is irrelevant feature while considering Performance.
#
# With the growing prevalence of competitive eSports, there is a need for rich user data and analysis for improving skill. By exploring the data, we found valuable insights into the strategies and metrics that yield the best player performance.
#
# Goal: Predict final leaderboard placements based on player in-game statistics.
#
# The models used are Lenear Regression, Random Forest, XGBoost, ANN and CNN. Out of all these Random forest needed sampling as the machine was not able to perform the large data set, so out of 4446965, 1050000 are choosen for Random forest.
#
# #### Out of thses models Random Forest Regressor gives r2 score of 92.77% and Mean Squared Error of 0.006827 with sampled data.
# #### CNN with tensorflow gives the best result of Mean Squared Error : 0.00717 and R2 score : 92.37% for the whole data set.
#
# Various steps such as Preprocessing, Encoding , prediction using Machine Learning models are used to achieve our objective.
# Visualization is done by Matplotlib,seaborn and Power BI

# %% [markdown]
# ##1.Requirements
# - The input data which is given by Internship team Datamites. It is an excel file(.csv) with 4446965 rows and 29 columns. The data set is for predicting the final placement of a player in PUBG game. So the data is analyzed to predict the finishing placement of a player. The data is analyzed with Jupyter notebook and Colab in Python language.

# %% [markdown]
# Before starting lets understand our data set with below explinations for the each features present in our data set.
#
# #### Feature descriptions
# - DBNOs - Number of enemy players knocked.
# - assists - Number of enemy players this player damaged that were killed by teammates.
# - boosts - Number of boost items used.
# - damageDealt - Total damage dealt. Note: Self inflicted damage is subtracted.
# - headshotKills - Number of enemy players killed with headshots.
# - heals - Number of healing items used.
# - Id - Player’s Id
# - killPlace - Ranking in match of number of enemy players killed.
# - killPoints - Kills-based external ranking of player. (Think of this as an Elo ranking where only kills matter.) If there is a value other than -1 in rankPoints, then any 0 in killPoints should be treated as a “None”.
# - killStreaks - Max number of enemy players killed in a short amount of time.
# - kills - Number of enemy players killed.
# - longestKill - Longest distance between player and player killed at time of death. This may be misleading, as downing a player and driving away may lead to a large longestKill stat.
# - matchDuration - Duration of match in seconds.
# - matchId - ID to identify match. There are no matches that are in both the training and testing set.
# - matchType - String identifying the game mode that the data comes from. The standard modes are “solo”, “duo”, “squad”, “solo-fpp”, “duo-fpp”, and “squad-fpp”; other modes are from events or custom matches.
# - rankPoints - Elo-like ranking of player. This ranking is inconsistent and is being deprecated in the API’s next version, so use with caution. Value of -1 takes place of “None”.
# - revives - Number of times this player revived teammates.
# - rideDistance - Total distance traveled in vehicles measured in meters.
# - roadKills - Number of kills while in a vehicle.
# - swimDistance - Total distance traveled by swimming measured in meters.
# - teamKills - Number of times this player killed a teammate.
# - vehicleDestroys - Number of vehicles destroyed.
# - walkDistance - Total distance traveled on foot measured in meters.
# - weaponsAcquired - Number of weapons picked up.
# - winPoints - Win-based external ranking of player. (Think of this as an Elo ranking where only winning matters.) If there is a value other than -1 in rankPoints, then any 0 in winPoints should be treated as a “None”.
# - groupId - ID to identify a group within a match. If the same group of players plays in different matches, they will have a different groupId each time.
# - numGroups - Number of groups we have data for in the match.
# - maxPlace - Worst placement we have data for in the match. This may not match with numGroups, as sometimes the data skips over placements.
# - winPlacePerc - The target of prediction. This is a percentile winning placement, where 1 corresponds to 1st place, and 0 corresponds to last place in the match. It is calculated off of maxPlace, not numGroups, so it is possible to have missing chunks in a match.

# %% [markdown]
# ## 2.Analysis
# - The analysis is done by analyzing the various features of the data. It has 29 features which plays important role in analysis of data with many prespectives. Many packages such as numpy, pandas,etc., are used to analyze the fearures. The features are categorized into Numerical and Categorical Datas.
#
# #### Game can be played in different modes which is categorized as follows
# - solo  <-- solo,solo-fpp,normal-solo,normal-solo-fpp
# - duo   <-- duo,duo-fpp,normal-duo,normal-duo-fpp,crashfpp,crashtpp
# - squad <-- squad,squad-fpp,normal-squad,normal-squad-fpp,flarefpp,flaretpp
#
# #### Numerical Data
# - Numerical features are the values which varies in a particular range and classified as discrete, continuous, or timeseries based. The Numerical Features as follows,
#  1   Assists
#  2   Boosts
#  3   DamageDealt
#  4   DBNOs
#  5   HeadshotKills
#  6   Heals
#  7   KillPlace
#  8   KillPoints
#  9   Kills
#  10  KillStreaks
#  11  LongestKill
#  12  MatchDuration
#  13  MaxPlace
#  14  NumGroups
#  15  RankPoints
#  16  Revives
#  17  RideDistance
#  18  RoadKills
#  19  SwimDistance
#  20  TeamKills
#  21  VehicleDestroys
#  22  WalkDistance
#  23  WeaponsAcquired
#  24  WinPoints
#  25  WinPlacePerc
#
# #### Categorical Data
# - Categorical features are those which classify values into sets of similar samples but here the Categorical means the datas in Text format, these do not have any order . The categorical features as follows,
#  1  ID
#  2  GroupId
#  3  MatchId
#  4  MatchType
#
# #### Data Cleaning
# - The Data cleaning is the part of the Data science where the workflow of the project starts through this stage, because the damaged and missing data will lead to the disaster in the accuracy and quality of the model. If the data is already structured and cleaned, there is no need for the data cleaning. In this case, the given data is well structured but contains few outliers and one missing value.
#
# #### Outliers
# * Kills without movement (1 player)
# * Heals used are more than 35 (325 players)
# * longest kill more than 1000mt away (20 players)
# * Killing more than 30 (95 players)
# * weapons aquired more than 45 (198 players)
# These outliers has been dropped out of the data set.
#
# #### Analysis by Visualization
# - To perform the analysis by the visualisation of the data in various forms are used in this project. It is done by distributing the data and visualize using plotting with matplotlib pyplots and Seaborn package.
#
# #### Machine learning model
# The machine learning models used in this project are
#
# * Linear Regression
# * Random forest Regressor (with sampled data set only)
# * XGBoost regressor
# * ANN
# * CNN with Tensorflow
#
# The train and test data are divided and fitted into the model and passed through the machine learning. The predicted data and test data achieved the accuracy rate of,
#
# * Linear Regression (83.3%)
# * Random Forest (92.69%)
# * XGBoost (89.92%)
# * ANN without hidden layers (87.79%) ANN with hidden layers (91.24%)
# * CNN (92.33 for train, 92.37 for test data)

# %% [markdown]
# # Summary
# The 4 machine learning model has been fitted and predicted with the r2 and mean squared error. The objective of this project is to predict the results from the analysis and machine learning model.
#
# ### Objective 1 : Win Place Prediction based on correlated features.
# - According to the data set provided below features have the high correlation with win place.
# -assists
# -boosts
# -damageDealt
# -DBNOs
# -headshotKills
# -heals
# -killPlace
# -killPoints
# -kills
# -killStreaks
# -longestKill
# -matchDuration
# -maxPlace
# -numGroups
# -rankPoints
# -revives
# -rideDistance
# -roadKills
# -swimDistance
# -teamKills
# -vehicleDestroys
# -walkDistance
# -weaponsAcquired
# -winPoints
#
# ## Objective 2 : Factors affectin the win place with high Correlation
# - walkDistance
# -weaponsAcquired
# -revives
# -rideDistance
# -kills
# -killStreaks
# -longestKill
# -assists
# -boosts
# -damageDealt
# -DBNOs
# -headshotKills
# -heals
# -killPlace
#
# ## Objective 3: A Trained model which can predict the Win Place Predection of players
# - Linear Regression (83.3%)
# -Random Forest (92.69%)
# -XGBoost (89.92%)
# -ANN without hidden layers (87.79%) ANN with hidden layers (91.24%)
# -CNN (92.33 for train, 92.37 for test data)
#
# ## Objective 4: Recommendation For Winning Place
# - Player should travel either walk,swim or ride through the entire map which helps in being alive and gather more equipment or boosts.
# - Player should make as much as head shot kills possible in order to achive good win place predection.
# - Longest kill or more damages done to the other players helps in improving Winner place
# - Vehicles destroyed is directly proportional for win place.
# - Acquiring good weapons and more Kills done gives good stats for a player
# - In case of squad matches team kills, revives, DBNO's, assist have much vital role, so improving them can give better winning placements.
