# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
pubg = pd.read_csv('pubg.csv')
pubg.head()
# Out:
#                Id         groupId         matchId  assists  boosts  \
# 0  7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1  eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2  1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3  4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4  315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
#
#    damageDealt  DBNOs  headshotKills  heals  killPlace  ...  revives  \
# 0         0.00      0              0      0         60  ...        0
# 1        91.47      0              0      0         57  ...        0
# 2        68.00      0              0      0         47  ...        0
# 3        32.90      0              0      0         75  ...        0
# 4       100.00      0              0      0         45  ...        0
#
#    rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# 0        0.0000          0          0.00          0               0
# ...

# %%
pubg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4446966 entries, 0 to 4446965
# Data columns (total 29 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Id               object
#  1   groupId          object
#  2   matchId          object
#  3   assists          int64
#  4   boosts           int64
#  5   damageDealt      float64
#  6   DBNOs            int64
#  7   headshotKills    int64
#  8   heals            int64
#  9   killPlace        int64
#  10  killPoints       int64
#  11  kills            int64
#  12  killStreaks      int64
#  13  longestKill      float64
#  14  matchDuration    int64
#  15  matchType        object
#  16  maxPlace         int64
#  17  numGroups        int64
#  18  rankPoints       int64
#  19  revives          int64
#  20  rideDistance     float64
#  21  roadKills        int64
#  22  swimDistance     float64
#  23  teamKills        int64
#  24  vehicleDestroys  int64
#  25  walkDistance     float64
# ...

# %%
pubg.shape
# Out:
# (4446966, 29)

# %%
pubg.isnull().sum()
# Out:
# Id                 0
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       1
# dtype: int64

# %%
pubg.dropna(inplace=True)

# %%
pubg.isnull().sum()
# Out:
# Id                 0
# groupId            0
# matchId            0
# assists            0
# boosts             0
# damageDealt        0
# DBNOs              0
# headshotKills      0
# heals              0
# killPlace          0
# killPoints         0
# kills              0
# killStreaks        0
# longestKill        0
# matchDuration      0
# matchType          0
# maxPlace           0
# numGroups          0
# rankPoints         0
# revives            0
# rideDistance       0
# roadKills          0
# swimDistance       0
# teamKills          0
# vehicleDestroys    0
# walkDistance       0
# weaponsAcquired    0
# winPoints          0
# winPlacePerc       0
# dtype: int64

# %%
pubg.describe(include=np.number).drop('count').T
# Out:
#                         mean          std    min     25%        50%  \
# assists             0.233815     0.588573    0.0     0.0     0.0000
# boosts              1.106908     1.715794    0.0     0.0     0.0000
# damageDealt       130.717167   170.780629    0.0     0.0    84.2400
# DBNOs               0.657876     1.145743    0.0     0.0     0.0000
# headshotKills       0.226820     0.602155    0.0     0.0     0.0000
# heals               1.370148     2.679982    0.0     0.0     0.0000
# killPlace          47.599361    27.462931    1.0    24.0    47.0000
# killPoints        505.006156   627.504921    0.0     0.0     0.0000
# kills               0.924784     1.558445    0.0     0.0     0.0000
# killStreaks         0.543955     0.710972    0.0     0.0     0.0000
# longestKill        22.997600    50.972623    0.0     0.0     0.0000
# matchDuration    1579.506793   258.738814  133.0  1367.0  1438.0000
# maxPlace           44.504680    23.828099    2.0    28.0    30.0000
# ...

# %%
for c in ['Id','groupId','matchId']:
    print(f'unique [{c}] count:', pubg[c].nunique())
# we can do this without loop also by print function alone
# Out:
# unique [Id] count: 4446965
# unique [groupId] count: 2026744
# unique [matchId] count: 47964

# %%
pubg['matchType'].unique()
# Out:
# array(['squad-fpp', 'duo', 'solo-fpp', 'squad', 'duo-fpp', 'solo',
#        'normal-squad-fpp', 'crashfpp', 'flaretpp', 'normal-solo-fpp',
#        'flarefpp', 'normal-duo-fpp', 'normal-duo', 'normal-squad',
#        'crashtpp', 'normal-solo'], dtype=object)

# %% [raw]
# solo  <-- solo,solo-fpp,normal-solo,normal-solo-fpp
# duo   <-- duo,duo-fpp,normal-duo,normal-duo-fpp,crashfpp,crashtpp
# squad <-- squad,squad-fpp,normal-squad,normal-squad-fpp,flarefpp,flaretpp

# %%
function = lambda x: 'solo' if ('solo' in x) else 'duo' if ('duo' in x) or ('crash' in x) else 'squad'
pubg['matchType'] = pubg['matchType'].apply(function)
pubg.groupby('matchId')['matchType'].first().value_counts()
# Out:
# squad    25646
# duo      14224
# solo      8094
# Name: matchType, dtype: int64

# %%
function = lambda x: 'solo' if ('solo' in x) else 'duo' if ('duo' in x) or ('crash' in x) else 'squad'
pubg['matchType'] = pubg['matchType'].apply(function)
pubg.groupby('matchId')['matchType'].first().value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
print((pubg.numGroups == pubg.maxPlace).sum())
print((pubg.numGroups != pubg.maxPlace).sum())
# Out:
# 1241089
# 3205876

# %%
match = pubg.groupby(['matchType','matchId']).size().to_frame('players in match')
group = pubg.groupby(['matchType','matchId','groupId']).size().to_frame('players in group')

# %%
match.groupby('matchType').describe().T
# Out:
# matchType                        duo         solo         squad
# players in match count  14224.000000  8094.000000  25646.000000
#                  mean      92.985658    89.042748     93.723193
#                  std        9.428293    20.829687      8.070507
#                  min        7.000000     2.000000      5.000000
#                  25%       92.000000    93.000000     93.000000
#                  50%       95.000000    95.000000     95.000000
#                  75%       97.000000    97.000000     97.000000
#                  max      100.000000   100.000000    100.000000

# %%
group.groupby('matchType').describe().T
# Out:
# matchType                         duo           solo          squad
# players in group count  645041.000000  693493.000000  688210.000000
#                  mean        2.050456       1.039249       3.492575
#                  std         0.540953       0.431038       1.739234
#                  min         1.000000       1.000000       1.000000
#                  25%         2.000000       1.000000       3.000000
#                  50%         2.000000       1.000000       3.000000
#                  75%         2.000000       1.000000       4.000000
#                  max        72.000000      64.000000      74.000000

# %%
print(group['players in group'].nlargest(5))
del match,group
# Out:
# matchType  matchId         groupId
# squad      b30f3d87189aa6  14d6b54cdec6bc    74
# duo        3e029737889ce9  b8275198faa03b    72
# solo       41a634f62f86b7  128b07271aa012    64
# duo        7e93ce71ac6f61  7385e5fe214021    49
# squad      3c2531adf5b942  e52a2e6ca30474    36
# Name: players in group, dtype: int64

# %%
group = pubg.groupby(['matchId','groupId','matchType'])['Id'].count().to_frame('players').reset_index()
group.loc[group['players'] > 4, 'players'] = '5+'
group['players'] = group['players'].astype(str)

fig, ax = plt.subplots(1, 3, figsize=(16, 4))
for mt, ax in zip(['solo','duo','squad'], ax.ravel()):
    ax.set_xlabel(mt)
    group[group['matchType'] == mt]['players'].value_counts().sort_index().plot.bar(ax=ax)

# %% [markdown]
# ### match-duration (min and max)

# %%
pubg[pubg['matchDuration']==pubg['matchDuration'].min()].head()
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 1206365  28f2bb56074e95  311a5a9adf1a96  e5a77433bc436f        0       0
# 2109739  2a5f4f18fe9e86  f290930a32548a  e5a77433bc436f        0       0
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace  ...  revives  \
# 1206365        100.0      0              1      0          1  ...        0
# 2109739          0.0      0              0      0          2  ...        0
#
#          rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# 1206365           0.0          0           0.0          0               0
# 2109739           0.0          0           0.0          0               0
#
#          walkDistance  weaponsAcquired  winPoints  winPlacePerc
# 1206365          0.28                2          0           1.0
# 2109739          0.00                2          0           0.0
#
# [2 rows x 29 columns]

# %%
max_dur=pubg[pubg['matchDuration']==pubg['matchDuration'].max()]

# %%
max_dur.shape
# Out:
# (97, 29)

# %%
max_dur.head(10)
# Out:
#                     Id         groupId         matchId  assists  boosts  \
# 130663  8089c9ef1fa09e  3c909156e89431  f8e02cb4c82d7d        0       0
# 139317  3049d51e07bab3  4086a790e99513  f8e02cb4c82d7d        0       0
# 146220  cb3902c30f688c  65400d5cf84ead  f8e02cb4c82d7d        0       0
# 246201  80e022ce3a64ff  b668e37229bb2d  f8e02cb4c82d7d        0       1
# 268239  0e50a3a859d3ab  9dcca2c1beb072  f8e02cb4c82d7d        0       0
# 428357  e0badab7b895fa  561c30a00114d0  f8e02cb4c82d7d        0       0
# 501414  6120a72add1a0d  4a814834f56373  f8e02cb4c82d7d        0       2
# 501423  3d126d74708361  e53edd55b065bc  f8e02cb4c82d7d        0       0
# 609020  81099bda1beca7  b9a58739a9a1ef  f8e02cb4c82d7d        1       4
# 630403  54e4c8c8576436  c255e4d588af70  f8e02cb4c82d7d        0       0
#
#         damageDealt  DBNOs  headshotKills  heals  killPlace  ...  revives  \
# 130663         0.00      0              0      0         72  ...        0
# ...

# %% [markdown]
# ### kill place

# %%
pubg.groupby(['matchType'])['killPlace'].describe()[['min','mean','max']]
# Out:
#            min       mean    max
# matchType
# duo        1.0  47.471473  100.0
# solo       1.0  47.457529  100.0
# squad      1.0  47.712260  101.0

# %% [raw]
# kill place 101 is not possible for a game as max 100 players are allowed
# so we ll eliminate the ouytlier

# %%
pubg[pubg['killPlace']== 101.0]
# Out:
#                      Id         groupId         matchId  assists  boosts  \
# 3679420  a1e45f366ad76f  05c7966baad337  fe57e25e37dbfd        0       0
#
#          damageDealt  DBNOs  headshotKills  heals  killPlace  ...  revives  \
# 3679420        66.65      0              0      0        101  ...        0
#
#          rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# 3679420           0.0          0           0.0          0               0
#
#          walkDistance  weaponsAcquired  winPoints  winPlacePerc
# 3679420         8.277                1          0           0.0
#
# [1 rows x 29 columns]

# %%
pubg.drop(labels=[3679420],axis=0,inplace=True)

# %%
pubg[pubg['killPlace']== 101.0]
# Out:
# Empty DataFrame
# Columns: [Id, groupId, matchId, assists, boosts, damageDealt, DBNOs, headshotKills, heals, killPlace, killPoints, kills, killStreaks, longestKill, matchDuration, matchType, maxPlace, numGroups, rankPoints, revives, rideDistance, roadKills, swimDistance, teamKills, vehicleDestroys, walkDistance, weaponsAcquired, winPoints, winPlacePerc]
# Index: []
#
# [0 rows x 29 columns]

# %%
plt.figure(figsize=(8,4))
col = 'killPlace'
sub = pubg[['winPlacePerc',col]].copy()
sub[col] = pd.cut(sub[col],[5*x for x in range(0,21)], right=True)
sub.groupby(col).mean()['winPlacePerc'].plot.bar()
# Out:
# <AxesSubplot:xlabel='killPlace'>

# %% [markdown]
# ### sorting out wrt killPlace and winplaceperc

# %%
sort = pubg[pubg['matchId']==pubg['matchId'].min()].sort_values(['winPlacePerc','killPlace'])

# %%
col = ['groupId','kills','winPlacePerc','killPlace']
sort[col]
# Out:
#                 groupId  kills  winPlacePerc  killPlace
# 3895898  3a6addfa0df938      0         0.000         94
# 3599150  3a6addfa0df938      0         0.000         95
# 4367296  236ab9e9c081b9      0         0.037         88
# 4131025  236ab9e9c081b9      0         0.037         89
# 3088817  236ab9e9c081b9      0         0.037         90
# ...                 ...    ...           ...        ...
# 1303528  ca058240046b4c      6         0.963          3
# 3637258  ca058240046b4c      5         0.963          6
# 2351120  ca058240046b4c      1         0.963         24
# 2848198  4d1bbbc19b9084      5         1.000          5
# 20251    4d1bbbc19b9084      1         1.000         23
#
# [95 rows x 4 columns]

# %%
sort.shape
# Out:
# (95, 29)

# %% [markdown]
# ### kill summary of data set

# %%
summ = pubg['matchType'].str.contains('solo')

# %%
solo_summ=pubg.loc[summ].groupby('matchId')['kills'].sum().describe()
solo_summ
# Out:
# count    8094.000000
# mean       83.420558
# std        27.592399
# min         0.000000
# 25%        84.000000
# 50%        89.000000
# 75%        92.000000
# max       786.000000
# Name: kills, dtype: float64

# %%
team_summ = pubg.loc[~summ].groupby('matchId')['kills'].sum().describe()
team_summ
# Out:
# count    39870.000000
# mean        86.212039
# std         17.268987
# min          0.000000
# 25%         83.000000
# 50%         87.000000
# 75%         90.000000
# max        687.000000
# Name: kills, dtype: float64

# %%
# for comparing side by side
pd.concat([solo_summ,team_summ],keys=['solo','team'],axis = 1).T
# Out:
#         count       mean        std  min   25%   50%   75%    max
# solo   8094.0  83.420558  27.592399  0.0  84.0  89.0  92.0  786.0
# team  39870.0  86.212039  17.268987  0.0  83.0  87.0  90.0  687.0

# %% [markdown]
# ### assist

# %%
solo_assists = pubg[pubg['matchType']== 'solo'].describe()['assists']
team_assists = pubg[pubg['matchType']!= 'solo'].describe()['assists']
pd.concat([solo_assists,team_assists],keys=['solo','team'],axis=1).T
# Out:
#           count      mean       std  min  25%  50%  75%   max
# solo   720712.0  0.062236  0.297540  0.0  0.0  0.0  0.0  22.0
# team  3726252.0  0.267001  0.624101  0.0  0.0  0.0  0.0  17.0

# %% [markdown]
# ### Damage Dealt

# %%
pubg['damageDealt'].head()
# Out:
# 0      0.00
# 1     91.47
# 2     68.00
# 3     32.90
# 4    100.00
# Name: damageDealt, dtype: float64

# %%
pubg['damageDealt'].describe()
# Out:
# count    4.446964e+06
# mean     1.307172e+02
# std      1.707806e+02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      8.424000e+01
# 75%      1.860000e+02
# max      6.616000e+03
# Name: damageDealt, dtype: float64

# %% [markdown]
# ### kill points, rankpoints, winpoints

# %%
fig, ax = plt.subplots(1, 3, figsize=(16, 4), sharey=True)

cols = ['killPoints','rankPoints','winPoints']
for col, ax in zip(cols, ax.ravel()): 
    pubg.plot.scatter(x=col, y='winPlacePerc', ax=ax)

# %% [markdown]
# ### winplaceperc

# %%
pubg['winPlacePerc'].describe()
# Out:
# count    4.446964e+06
# mean     4.728217e-01
# std      3.074049e-01
# min      0.000000e+00
# 25%      2.000000e-01
# 50%      4.583000e-01
# 75%      7.407000e-01
# max      1.000000e+00
# Name: winPlacePerc, dtype: float64

# %% [markdown]
# ### Model

# %% [markdown]
# * spliting data for solo matches

# %%
df = pubg[pubg['matchType']=='solo']
df.head()
df1 = pubg[pubg['matchType']=='solo-fpp']
print(df1.shape)
df2 = pubg[pubg['matchType']=='normal-solo-fpp']
print(df2.shape)
df3 = pubg[pubg['matchType']=='normal-solo']
print(df3.shape)
solo = pd.concat([df,df1,df2,df3],axis=0)
print(solo.shape)
# Out:
# (0, 29)
# (0, 29)
# (0, 29)
# (720712, 29)

# %%
for m in ['Id', 'groupId', 'matchId']:
    print(f'unique[{m}] count: ',solo[m].nunique())
# Out:
# unique[Id] count:  720712
# unique[groupId] count:  693493
# unique[matchId] count:  8094

# %%
solo.corrwith(solo.winPlacePerc)
# Out:
# assists            0.120039
# boosts             0.637369
# damageDealt        0.481302
# DBNOs                   NaN
# headshotKills      0.337827
# heals              0.401358
# killPlace         -0.757971
# killPoints         0.023767
# kills              0.475520
# killStreaks        0.447713
# longestKill        0.438195
# matchDuration     -0.010163
# maxPlace           0.093724
# numGroups          0.100875
# rankPoints         0.003315
# revives                 NaN
# rideDistance       0.318398
# roadKills          0.050082
# swimDistance       0.165086
# teamKills          0.024449
# vehicleDestroys    0.060818
# walkDistance       0.810892
# weaponsAcquired    0.596826
# winPoints          0.019797
# winPlacePerc       1.000000
# dtype: float64

# %% [markdown]
# * DBNO and Revives are irrelevent for solo matches so we ll drop these features for solo matches

# %%
solo.drop(['DBNOs','revives'],axis=1,inplace=True)

# %%
solo.corrwith(solo.winPlacePerc)
# Out:
# assists            0.120039
# boosts             0.637369
# damageDealt        0.481302
# headshotKills      0.337827
# heals              0.401358
# killPlace         -0.757971
# killPoints         0.023767
# kills              0.475520
# killStreaks        0.447713
# longestKill        0.438195
# matchDuration     -0.010163
# maxPlace           0.093724
# numGroups          0.100875
# rankPoints         0.003315
# rideDistance       0.318398
# roadKills          0.050082
# swimDistance       0.165086
# teamKills          0.024449
# vehicleDestroys    0.060818
# walkDistance       0.810892
# weaponsAcquired    0.596826
# winPoints          0.019797
# winPlacePerc       1.000000
# dtype: float64

# %% [markdown]
# * spliting data for dua matches

# %%
d1 = pubg[pubg['matchType']=='duo']
print('duo : ',d1.shape)
d2 = pubg[pubg['matchType']=='duo-fpp']
print('duo-fpp : ',d2.shape)
d3 = pubg[pubg['matchType']=='normal-duo']
print('normal-duo : ',d3.shape)
d4 = pubg[pubg['matchType']=='normal-duo-fpp']
print('normal-duo-fpp : ',d4.shape)
d5 = pubg[pubg['matchType']=='crashfpp']
print('crashfpp : ',d5.shape)
d6 = pubg[pubg['matchType']=='crashtpp']
print('crashtpp : ',d6.shape)
duo = pd.concat([d1,d2,d3,d4,d5,d6],axis=0)
print('total duo : ',duo.shape)
# Out:
# duo :  (1322628, 29)
# duo-fpp :  (0, 29)
# normal-duo :  (0, 29)
# normal-duo-fpp :  (0, 29)
# crashfpp :  (0, 29)
# crashtpp :  (0, 29)
# total duo :  (1322628, 29)

# %%
for m in ['Id', 'groupId', 'matchId']:
    print(f'unique[{m}] count: ',duo[m].nunique())
# Out:
# unique[Id] count:  1322628
# unique[groupId] count:  645041
# unique[matchId] count:  14224

# %%
duo.corrwith(duo.winPlacePerc)
# Out:
# assists            0.320169
# boosts             0.647790
# damageDealt        0.471523
# DBNOs              0.356358
# headshotKills      0.297502
# heals              0.446659
# killPlace         -0.744370
# killPoints         0.014359
# kills              0.446807
# killStreaks        0.405922
# longestKill        0.423718
# matchDuration     -0.000067
# maxPlace          -0.002485
# numGroups          0.010301
# rankPoints         0.007348
# revives            0.263870
# rideDistance       0.368065
# roadKills          0.038772
# swimDistance       0.152956
# teamKills          0.025659
# vehicleDestroys    0.073709
# walkDistance       0.827704
# weaponsAcquired    0.631161
# winPoints          0.008943
# winPlacePerc       1.000000
# dtype: float64

# %% [markdown]
# * spliting data for squad matches

# %%
s1 = pubg[pubg['matchType']=='squad']
print('squad : ',s1.shape)
s2 = pubg[pubg['matchType']=='squad-fpp']
print('squad-fpp : ',s2.shape)
s3 = pubg[pubg['matchType']=='normal-squad']
print('normal-squad : ',s3.shape)
s4 = pubg[pubg['matchType']=='normal-squad-fpp']
print('normal-squad-fpp : ',s4.shape)
s5 = pubg[pubg['matchType']=='flarefpp']
print('flarefpp : ',s5.shape)
s6 = pubg[pubg['matchType']=='flaretpp']
print('flaretpp : ',s6.shape)
sqd = pd.concat([s1,s2,s3,s4,s5,s6],axis=0)
print('total sqd : ',sqd.shape)
# Out:
# squad :  (2403624, 29)
# squad-fpp :  (0, 29)
# normal-squad :  (0, 29)
# normal-squad-fpp :  (0, 29)
# flarefpp :  (0, 29)
# flaretpp :  (0, 29)
# total sqd :  (2403624, 29)

# %%
for m in ['Id', 'groupId', 'matchId']:
    print(f'unique[{m}] count: ',sqd[m].nunique())
# Out:
# unique[Id] count:  2403624
# unique[groupId] count:  688210
# unique[matchId] count:  25646

# %%
sqd.corrwith(sqd.winPlacePerc)
# Out:
# assists            0.336333
# boosts             0.629018
# damageDealt        0.415684
# DBNOs              0.317433
# headshotKills      0.249042
# heals              0.431329
# killPlace         -0.695514
# killPoints         0.013580
# kills              0.390137
# killStreaks        0.351840
# longestKill        0.398809
# matchDuration     -0.010486
# maxPlace           0.000549
# numGroups          0.010481
# rankPoints         0.015702
# revives            0.275053
# rideDistance       0.339904
# roadKills          0.025326
# swimDistance       0.143380
# teamKills          0.013017
# vehicleDestroys    0.077630
# walkDistance       0.815314
# weaponsAcquired    0.559330
# winPoints          0.005198
# winPlacePerc       1.000000
# dtype: float64
